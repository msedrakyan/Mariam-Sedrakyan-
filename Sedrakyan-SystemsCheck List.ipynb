# %%
print ("Happy Friday!")
# Out:
# Happy Friday

# %% [markdown]
# # Data In Emerging Media And Technology
#
# ##  _My goals_
#
# I want to start by saying I am glad to be in this class. After the first week, I became more excited and ready to gain new knowledge from Dr. Silva. I am new to Python, so I understand this class will be challenging. However, I am prepared to accept all the challenges, aka. The assignments developed a solid knowledge I can use during my career journey.
#
# Additionally, my main goal is to have enough confidence in my knowledge at the end of the semester to find an internship where I can use everything I learn in the field.

# %% [markdown]
# ## _End of Semester checklist_
#
# 1. Get an internship
# 1. Meet new people in my field
# 1. Become more confident in my knowledge
# 1. Finish my EMAT 32210. All assignments completed and with good grades

# %% [markdown]
# ### Creative Coding Project
# [I aimed to create a continuous flow field where everything connects and becomes one!](https://editor.p5js.org/Mariam_S/full/TcBPrKr6J)
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Also, I tried to do an optional step, but I failed. Hopefully, we can cover it together during the next class.
